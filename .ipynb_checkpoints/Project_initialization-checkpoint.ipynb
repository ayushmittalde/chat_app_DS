# %% [markdown]
# ### Dependecies

# %%
import uuid
import socket
import threading
import random
import time

# %% [markdown]
# ### Node Class Definition Initialization and Setup

# %%
class Node:
    def __init__(self, is_leader=False):
        self.uuid = uuid.uuid4()
        self.is_leader = is_leader
        self.port = self.assign_free_port()
        self.multicast_address = "224.0.0.10"
        self.multicast_port = 55000
        self.message_history = []  
        self.group_participants = []  
        self.retry_count = 0
        self.max_retries = 5
        print(f"Node initialized with UUID: {self.uuid} on port: {self.port}")

    def assign_free_port(self):
        return random.randint(10000, 11000)

# %% [markdown]
# ### Multicast Listening and Message Handling

# %%
    def multicast_listen(self):
        sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
        sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        sock.bind((self.multicast_address, self.multicast_port))
        sock.setsockopt(socket.IPPROTO_IP, socket.IP_ADD_MEMBERSHIP, socket.inet_aton(self.multicast_address) + socket.inet_aton("0.0.0.0"))
        print("Listening to multicast messages...")
        while True:
            data, addr = sock.recvfrom(1024)
            self.handle_message(data.decode(), addr)
            
    def handle_message(self, message, addr):
        print(f"Received message: {message} from {addr}")
        if message.startswith("WANT_TO_JOIN"):
            if self.is_leader:
                self.send_join_response(addr)
        elif message.startswith("HEARTBEAT"):
            print("Heartbeat received from leader.")

# %% [markdown]
# ### Message Broadcasting and Leader Response

# %%
    def broadcast_message(self, message):
        sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
        sock.setsockopt(socket.IPPROTO_IP, socket.IP_MULTICAST_TTL, 2)
        sock.sendto(message.encode(), (self.multicast_address, self.multicast_port))

    def send_join_response(self, addr):
        response = {
            "last_messages": self.message_history[-20:],
            "participants": self.group_participants
        }
        self.broadcast_message(f"JOIN_RESPONSE {response}")

# %% [markdown]
# ### Add Joining and Hearbeat Simulation

# %%
def attempt_join(self):
    joined = False  
    for attempt in range(self.max_retries):
        delay = random.uniform(1, 5)
        print(f"Attempting to join (Attempt {attempt + 1}/{self.max_retries}). Waiting for {delay:.2f} seconds...")      
        self.broadcast_message(f"WANT_TO_JOIN {self.uuid}")        
        start_time = time.time()
        while time.time() - start_time < delay:
            if self.received_leader_response:
                print("Successfully joined the group.")
                joined = True
                break
            if self.received_leader_heartbeat:
                print("Heartbeat detected. Retrying join...")
                break
            time.sleep(0.1)  
        if joined:
            break
    if not joined:
        print("Failed to join after maximum retries.")
    else:
        print("Node successfully joined the group!")

def simulate_heartbeat(self):
    if self.is_leader:
        while True:
            print("Sending heartbeat...")
            self.broadcast_message("HEARTBEAT")
            time.sleep(5)

# %% [markdown]
# ### The whole class has to be run in one go so run the code below

# %%
class Node:
    def __init__(self, is_leader=False):
        self.uuid = uuid.uuid4()
        self.is_leader = is_leader
        self.port = self.assign_free_port()
        self.multicast_address = "224.0.0.10"
        self.multicast_port = 55000
        self.message_history = []  
        self.group_participants = []  
        self.retry_count = 0
        self.max_retries = 5
        self.received_leader_response = False
        self.received_leader_heartbeat = False
        print(f"Node initialized with UUID: {self.uuid} on port: {self.port}")

    def assign_free_port(self):
        # Assign a random port from a range
        return random.randint(10000, 11000)

    def multicast_listen(self):
        # Set up a socket to listen to multicast messages
        sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
        sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        sock.bind((self.multicast_address, self.multicast_port))

        # Add to multicast group
        sock.setsockopt(
            socket.IPPROTO_IP,
            socket.IP_ADD_MEMBERSHIP,
            socket.inet_aton(self.multicast_address) + socket.inet_aton("0.0.0.0")
        )

        print("Listening to multicast messages...")
        while True:
            data, addr = sock.recvfrom(1024)
            self.handle_message(data.decode(), addr)

    def broadcast_message(self, message):
        # Send a message to the multicast group
        sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM, socket.IPPROTO_UDP)
        sock.setsockopt(socket.IPPROTO_IP, socket.IP_MULTICAST_TTL, 2)
        sock.sendto(message.encode(), (self.multicast_address, self.multicast_port))

    def handle_message(self, message, addr):
        # Handle incoming messages
        print(f"Received message: {message} from {addr}")
        if message.startswith("WANT_TO_JOIN"):
            if self.is_leader:
                self.send_join_response(addr)
        elif message.startswith("JOIN_RESPONSE"):
            self.received_leader_response = True
        elif message.startswith("HEARTBEAT"):
            self.received_leader_heartbeat = True

    def send_join_response(self, addr):
        # Respond with the last 20 messages and participants
        response = {
            "last_messages": self.message_history[-20:],
            "participants": self.group_participants
        }
        print(f"Sending JOIN_RESPONSE to {addr}")
        self.broadcast_message(f"JOIN_RESPONSE {response}")

    def attempt_join(self):
        # Attempt to join the group
        joined = False
        for attempt in range(self.max_retries):
            delay = random.uniform(1, 5)
            print(f"Attempting to join (Attempt {attempt + 1}/{self.max_retries}). Waiting for {delay:.2f} seconds...")
            self.broadcast_message(f"WANT_TO_JOIN {self.uuid}")
            start_time = time.time()
            while time.time() - start_time < delay:
                if self.received_leader_response:
                    print("Successfully joined the group.")
                    joined = True
                    break
                if self.received_leader_heartbeat:
                    print("Heartbeat detected. Retrying join...")
                    break
                time.sleep(0.1)  # Small sleep to avoid busy waiting
            if joined:
                break
        if not joined:
            print("Failed to join after maximum retries.")
        else:
            print("Node successfully joined the group!")

    def simulate_heartbeat(self):
        # Leader sends periodic heartbeat
        if self.is_leader:
            while True:
                print("Sending heartbeat...")
                self.broadcast_message("HEARTBEAT")
                time.sleep(5)

# %% [markdown]
# ### Main

# %%
def main():
    is_leader = input("Is this node the leader? (yes/no): ").strip().lower() == "yes"
    node = Node(is_leader)
    listener_thread = threading.Thread(target=node.multicast_listen, daemon=True)
    listener_thread.start()

    if is_leader:
        heartbeat_thread = threading.Thread(target=node.simulate_heartbeat, daemon=True)
        heartbeat_thread.start()
    else:
        node.attempt_join()

# %%
main()
# Out:
# Is this node the leader? (yes/no):  yes
# Node initialized with UUID: 7e57f6e6-d753-4b69-999e-ee6b958612f9 on port: 10600
# Sending heartbeat...
# Listening to multicast messages...
# Received message: HEARTBEAT from ('192.168.0.102', 62566)Received message: HEARTBEAT from ('192.168.0.102', 62566)
# Received message: HEARTBEAT from ('192.168.0.102', 62566)
# Received message: HEARTBEAT from ('192.168.0.102', 62566)

# %%
main()
# Out:
# Sending heartbeat...
# Received message: HEARTBEAT from ('192.168.0.102', 58489)
# Received message: HEARTBEAT from ('192.168.0.102', 58489)
# Received message: HEARTBEAT from ('192.168.0.102', 58489)
# Received message: HEARTBEAT from ('192.168.0.102', 58489)
# Is this node the leader? (yes/no):  no
# Node initialized with UUID: 6ccf9e54-28cc-47be-a1e0-00c20a6786e2 on port: 10554
# Attempting to join (Attempt 1/5). Waiting for 4.80 seconds...
# Listening to multicast messages...
# Received message: WANT_TO_JOIN 6ccf9e54-28cc-47be-a1e0-00c20a6786e2 from ('192.168.0.102', 62881)
# Received message: WANT_TO_JOIN 6ccf9e54-28cc-47be-a1e0-00c20a6786e2 from ('192.168.0.102', 62881)
# Sending JOIN_RESPONSE to ('192.168.0.102', 62881)
# Received message: WANT_TO_JOIN 6ccf9e54-28cc-47be-a1e0-00c20a6786e2 from ('192.168.0.102', 62881)
# Received message: WANT_TO_JOIN 6ccf9e54-28cc-47be-a1e0-00c20a6786e2 from ('192.168.0.102', 62881)
# Sending JOIN_RESPONSE to ('192.168.0.102', 62881)
# Received message: WANT_TO_JOIN 6ccf9e54-28cc-47be-a1e0-00c20a6786e2 from ('192.168.0.102', 62881)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 59827)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 58312)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 59827)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 59827)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 59827)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 58312)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 58312)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 58312)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 59827)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 58312)
# Successfully joined the group.
# Node successfully joined the group!

# %%
main()
# Out:
# Sending heartbeat...
# Received message: HEARTBEAT from ('192.168.0.102', 59511)
# Received message: HEARTBEAT from ('192.168.0.102', 59511)
# Received message: HEARTBEAT from ('192.168.0.102', 59511)
# Received message: HEARTBEAT from ('192.168.0.102', 59511)
# Received message: HEARTBEAT from ('192.168.0.102', 59511)
# Is this node the leader? (yes/no):  no
# Node initialized with UUID: d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd on port: 10859
# Listening to multicast messages...
# Attempting to join (Attempt 1/5). Waiting for 1.48 seconds...
# Received message: WANT_TO_JOIN d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd from ('192.168.0.102', 52901)
# Received message: WANT_TO_JOIN d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd from ('192.168.0.102', 52901)
# Received message: WANT_TO_JOIN d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd from ('192.168.0.102', 52901)
# Received message: WANT_TO_JOIN d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd from ('192.168.0.102', 52901)
# Sending JOIN_RESPONSE to ('192.168.0.102', 52901)
# Received message: WANT_TO_JOIN d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd from ('192.168.0.102', 52901)
# Received message: WANT_TO_JOIN d689afc9-b941-4db9-b1a9-6b3d3b0fb8cd from ('192.168.0.102', 52901)
# Sending JOIN_RESPONSE to ('192.168.0.102', 52901)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 49760)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 63020)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 49760)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 49760)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 49760)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 63020)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 63020)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 63020)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 49760)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 63020)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 49760)
# Received message: JOIN_RESPONSE {'last_messages': [], 'participants': []} from ('192.168.0.102', 63020)
# Successfully joined the group.
# Node successfully joined the group!
